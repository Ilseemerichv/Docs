# %% [markdown]
# Task 1
# Create a flowchart and pseudocode for these cases:
# Define if a given number is prime or not.
# A prime number (or a prime) is a natural number greater than 1 that is not a product of two smaller natural numbers.
# Or, it is a natural number that can be divided only by 1 and itself.
#
# Task 2
# French tax deduction
# Rule 1: Income Threshold Based on Tax Reference Income (RFR)
# To qualify for certain tax reductions or exemptions, the taxpayer's tax reference income (revenu fiscal de référence) must fall below specific annual limits set by the French government.
# Rule 2: Family Quotient Advantage
# Taxpayers receive reductions based on their family situation, through the “quotient familial” system.
# The more dependents (children, elderly relatives, etc.), the more parts are counted in your household, which reduces taxable income.
# There is a limit to the tax reduction per half-share, which was €1,759 in 2024.
# Rule 3: Eligibility Through Deductible Expenses and Credits
# Certain life expenses can make taxpayers eligible for tax reductions or credits, such as:
# Home help services (e.g., cleaners, nannies): 50% credit on eligible costs
# Childcare for children under 6: 50% credit on up to €3,500 of expenses
# Energy-saving home improvements: Eligible for the “MaPrimeRénov” or other eco-tax benefits

# %% [markdown]
# # Task 1

# %% [markdown]
# FLOWCHART
#
# Start
#
# -Input the number n
# -Check if n <= 1
# Yes -> Output: "False" -> End
# No -> Continue
#
# -Initialize i to 2
# -Is i <= √n?
# No -> Output "True" -> End
# Yes -> Continue
#
# -Check if n remainder i == 0
# Yes -> Output "False" -> End
# No -> Increment i by 1 -> Go back to step 4

# %% [markdown]
# PSEUDOCODE
#
# Start
# Read number
# If number <= 1 then
#     Print "False"
# Else
#     For i from 2 to number-1 do
#         If number % i == 0 then
#             Print "False"
#     End For
#     Print "True"
# End

# %%
def is_prime(number):
    if number <= 1:
        return False
    for i in range(2, number):
        if number % i == 0:
            return False
    return True

#Test
number = int(input("Enter a number: "))
if is_prime(number):
    print("It is a prime number.")
else:

    print("It is not a prime number.")
# Out:
# Enter a number: 2
# It is a prime number.

# %% [markdown]
# #Task 2

# %% [markdown]
# FLOWCHART
#
# Start
#
# -Ask user for Tax Reference Income (RFR)
#
# -Is RFR < income threshold?
#
# Yes -> Eligible_Income = True
#
# No -> Eligible_Income = False
#
# -Ask user for number of household parts (quotient familial)
#
# -Compute Tax Reduction: (number of parts - 1) * €1759
#
# -Ask for home help expenses, compute 50% credit
#
# -Ask for childcare expenses, compute 50% of max €3,500
#
# -Ask for energy-saving improvements, calculate eco-tax credit
#
# -Any deduction or credit > 0?
#
# Yes -> Print "Eligible for tax deduction"
#
# No -> Print "Not eligible"
#
# End

# %% [markdown]
# PSEUDOCODE
#
# Start
#
# -Step 1: Check income threshold
# Ask "Enter your Tax Reference Income (RFR):"
# If RFR < Annual_Limit then
#     Eligible_Income <- True
# Else
#     Eligible_Income <- False
# End If
#
# -Step 2: Calculate Family Quotient
# Ask "Enter number of household parts (based on dependents):"
# Tax_Reduction <- min((Number_of_Parts - 1) * 1759, Maximum_Allowed_Reduction)
#
# -Step 3: Check for deductible expenses
# Ask "Enter amount spent on home help services:"
# Home_Help_Credit <- 0.5 * Home_Help_Amount
#
# Ask "Enter amount spent on childcare for children under 6 (max €3,500):"
# Childcare_Amount <- min(Childcare_Input, 3500)
# Childcare_Credit <- 0.5 * Childcare_Amount
#
# Ask "Enter amount spent on energy-saving home improvements:"
# Energy_Credit <- Calculate_Eco_Tax_Credit(Energy_Amount)
#
# -Final decision
# If Eligible_Income = True OR Tax_Reduction > 0 OR
#    Home_Help_Credit > 0 OR Childcare_Credit > 0 OR Energy_Credit > 0 then
#     Print "You are eligible for one or more tax deductions or credits."
# Else
#     Print "You are not eligible for tax deductions."
# End If
#
# End
