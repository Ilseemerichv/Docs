# %% [markdown]
# ## Challenge 2: Sets
#
# There are a lot to learn about Python Sets and the information presented in the lesson is limited due to its length. To learn Python Sets in depth you are strongly encouraged to review the W3Schools tutorial on [Python Sets Examples and Methods](https://www.w3schools.com/python/python_sets.asp) before you work on this lab. Some difficult questions in this lab have their solutions in the W3Schools tutorial.
#
# #### First, import the Python `random` library.

# %%
import random

# %% [markdown]
# #### In the cell below, create a list named `sample_list_1` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * Each value in the list is unique.
#
# Print `sample_list_1` to review its values
#
# *Hint: use `random.sample` ([reference](https://docs.python.org/3/library/random.html#random.sample)).*

# %%
sample_list_1 = random.sample(range(0, 101), 80)
print(sample_list_1)
# Out:
# [79, 92, 6, 59, 74, 14, 69, 66, 37, 21, 55, 7, 80, 68, 46, 83, 34, 12, 48, 33, 67, 78, 4, 54, 43, 31, 29, 0, 87, 62, 13, 30, 99, 64, 96, 42, 2, 23, 71, 88, 60, 82, 93, 8, 32, 58, 75, 90, 85, 100, 16, 91, 52, 1, 89, 81, 24, 97, 72, 65, 44, 5, 38, 25, 36, 15, 63, 41, 22, 98, 40, 94, 18, 51, 50, 28, 73, 77, 86, 70]

# %% [markdown]
# #### Convert `sample_list_1` to a set called `set1`. Print the length of the set. Is its length still 80?

# %%
set1 = set(sample_list_1)
len(set1)
# Out:
# 80

# %% [markdown]
# #### Create another list named `sample_list_2` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * The values in the list don't have to be unique.
#
# *Hint: Use a FOR loop.*

# %%
sample_list_2 = random.choices(range(101), k=80)
print(sample_list_2)
# Out:
# [34, 96, 45, 82, 41, 7, 42, 23, 88, 85, 34, 44, 18, 89, 42, 33, 50, 59, 80, 62, 0, 38, 2, 8, 38, 49, 95, 90, 5, 55, 27, 12, 43, 5, 9, 48, 79, 80, 51, 75, 83, 19, 41, 95, 48, 53, 84, 95, 54, 36, 98, 76, 94, 60, 38, 90, 1, 60, 59, 5, 30, 95, 60, 49, 20, 57, 69, 96, 53, 29, 50, 43, 98, 27, 88, 40, 18, 61, 0, 86]

# %% [markdown]
# #### Convert `sample_list_2` to a set called `set2`. Print the length of the set. Is its length still 80?

# %%
set2 = set(sample_list_2)
len(set2)

#When you convert a list with repeated values into a set, duplicates are removed. That’s why the total number of elements is no longer 80.
# Out:
# 54

# %% [markdown]
# #### Identify the elements present in `set1` but not in `set2`. Assign the elements to a new set named `set3`.

# %%
set3 = set1 - set2
print(set3)
# Out:
# {4, 6, 13, 14, 15, 16, 21, 22, 24, 25, 28, 31, 32, 37, 46, 52, 58, 63, 64, 65, 66, 67, 68, 70, 71, 72, 73, 74, 77, 78, 81, 87, 91, 92, 93, 97, 99, 100}

# %% [markdown]
# #### Identify the elements present in `set2` but not in `set1`. Assign the elements to a new set named `set4`.

# %%
set4 = set2 - set1
print(set4)
# Out:
# {9, 76, 45, 49, 19, 20, 53, 84, 57, 27, 61, 95}

# %% [markdown]
# #### Now Identify the elements shared between `set1` and `set2`. Assign the elements to a new set named `set5`.

# %%
set5 = set1 & set2
print(set5)
# Out:
# {0, 1, 2, 5, 7, 8, 12, 18, 23, 29, 30, 33, 34, 36, 38, 40, 41, 42, 43, 44, 48, 50, 51, 54, 55, 59, 60, 62, 69, 75, 79, 80, 82, 83, 85, 86, 88, 89, 90, 94, 96, 98}

# %% [markdown]
# #### What is the relationship among the following values:
#
# * len(set1)
# * len(set2)
# * len(set3)
# * len(set4)
# * len(set5)
#
# Use a math formular to represent that relationship. Test your formular with Python code.

# %%
len(set1) + len(set2) == len(set3) + len(set4) + 2 * len(set5)
# Out:
# True

# %% [markdown]
# #### Create an empty set called `set6`.

# %%
set6 = set()

# %% [markdown]
# #### Add `set3` and `set5` to `set6` using the Python Set `update` method.

# %%
set6.update(set3, set5)
print(set6)
# Out:
# {0, 1, 2, 4, 5, 6, 7, 8, 12, 13, 14, 15, 16, 18, 21, 22, 23, 24, 25, 28, 29, 30, 31, 32, 33, 34, 36, 37, 38, 40, 41, 42, 43, 44, 46, 48, 50, 51, 52, 54, 55, 58, 59, 60, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 77, 78, 79, 80, 81, 82, 83, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 96, 97, 98, 99, 100}

# %% [markdown]
# #### Check if `set1` and `set6` are equal.

# %%
set1 == set6
# Out:
# True

# %% [markdown]
# #### Check if `set1` contains `set2` using the Python Set `issubset` method. Then check if `set1` contains `set3`.*

# %%
set2.issubset(set1)
# Out:
# False

# %%
set3.issubset(set1)
# Out:
# True

# %% [markdown]
# #### Using the Python Set `union` method, aggregate `set3`, `set4`, and `set5`. Then aggregate `set1` and `set2`.
#
# #### Check if the aggregated values are equal.

# %% [markdown]
# #### Using the `pop` method, remove the first element from `set1`.

# %%
aggregated_sets_1 = set3.union(set4, set5)
print(aggregated_sets_1)
# Out:
# {0, 1, 2, 4, 5, 6, 7, 8, 9, 12, 13, 14, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 32, 33, 34, 36, 37, 38, 40, 41, 42, 43, 44, 45, 46, 48, 49, 50, 51, 52, 53, 54, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100}

# %%
aggregated_sets_2 = set1.union(set2)
print(aggregated_sets_2)
# Out:
# {0, 1, 2, 4, 5, 6, 7, 8, 9, 12, 13, 14, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 32, 33, 34, 36, 37, 38, 40, 41, 42, 43, 44, 45, 46, 48, 49, 50, 51, 52, 53, 54, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100}

# %%
aggregated_sets_1 == aggregated_sets_2
# Out:
# True

# %% [markdown]
# #### Remove every element in the following list from `set1` if they are present in the set. Print the remaining elements.
#
# ```
# list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
# ```

# %%
list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
for i in list_to_remove:
  if i in set1:
        set1.remove(i)
print(set1)
# Out:
# {0, 2, 4, 5, 6, 7, 8, 12, 13, 14, 15, 16, 18, 22, 23, 24, 25, 28, 30, 32, 33, 34, 36, 37, 38, 40, 42, 43, 44, 46, 48, 50, 52, 54, 55, 58, 60, 62, 63, 64, 65, 66, 67, 68, 70, 72, 73, 74, 75, 77, 78, 80, 82, 83, 85, 86, 87, 88, 90, 92, 93, 94, 96, 97, 98, 100}

# %%
len(set1)
# Out:
# 66
